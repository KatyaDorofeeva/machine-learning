# %% [markdown]
# #  Linear Model Selection and Regularization
#     Goal:
#     Produce a model with l2 regularization, with a statistically significant improvement over a model without regularization.
#     Produce a model with l1 regularization, with a statistically significant improvement over a model without regularization.
#     Produce a model with both l1 and l2 regularization terms, with a statistically significant improvement over a model without regularizatio
#     Produce a logistic regression model with a statistically significant improvement over the null model (a model without input variables)
#     Produce a generalized additive model with a statistically significant improvement over the null model (a model without input variables).

# %% [markdown]
# Dataset(s) needed:
# Kaggle House Prices (https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)

# %%
import pandas as pd

train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <h3> Q.1. Drop the Id columns from both train and test as these are not needed for prediction</h3>

# %%
#TODO
train.drop('Id',  axis = 1, inplace = True)
display(train.head())
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 1         Lvl    AllPub       FR2    ...            0    NaN   NaN
# 2         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 3         Lvl    AllPub    Corner    ...            0    NaN   NaN
# 4         Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         NaN       0      2    2008        WD         Normal     208500
# ...

# %% [markdown]
# <h3> Q.2. Visualize a scatter plot of 'GrLivArea' in the x-axis and 'SalePrice' in the y-axis. Can you spot any outliers?
# </h3>

# %%
import matplotlib.pyplot as plt

#TODO
x  =  train['GrLivArea']
y = train['SalePrice']
plt.scatter(x,y )
plt.xlabel('Live Area')
plt.ylabel('Sale Price')
plt.title('scatter plot')
plt.show()

# %% [markdown]
# <h3> Q.3. Remove outliers in the data for all GrLivArea greater than 4000 then check the scatter plot again</h3>

# %%
# Remove outliers for train['GrLivArea']>4000
#TODO
import numpy as np
# np.where(train['GrLivArea']>4000, NaN, train['GrLivArea']) 
train.loc[train['GrLivArea'] > 4000, 'GrLivArea'] = np.NaN

#TODO: Scatter plot
x  =  train['GrLivArea']
y = train['SalePrice']
plt.scatter(x,y )
plt.show()

# %% [markdown]
# <h3> Q.4.0 Convert categorical variable into dummy variables using pandas get_dummies API</h3>

# %%
train = pd.get_dummies(train)
  


train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0          2003       196.0         706           0          ...
# 1          1976         0.0         978           0          ...
# 2          2002       162.0         486           0          ...
# 3          1970         0.0         216           0          ...
# 4          2000       350.0         655           0          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %% [markdown]
# <h3> Q.4.1 Impute missing data by the mean of each column.</h3>

# %%
#TODO
#train.isnull().sum()
means = train.mean()
train = train.fillna(means)
#train.fillna(train.mean())
train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0          2003       196.0         706           0          ...
# 1          1976         0.0         978           0          ...
# 2          2002       162.0         486           0          ...
# 3          1970         0.0         216           0          ...
# 4          2000       350.0         655           0          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %% [markdown]
# <h3> Q.4.2 Generate train test split 70/30</h3>

# %%
from sklearn.model_selection import train_test_split

#TODO
train_set, test_set = train_test_split(train, test_size=0.3, random_state=42)

train_set.head(10)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 135           20    80.000000    10400            7            6       1970
# 1452         180    35.000000     3675            5            5       2005
# 762           60    72.000000     8640            7            5       2009
# 932           20    84.000000    11670            9            5       2006
# 435           60    43.000000    10667            7            6       1996
# 629           80    82.000000     9020            6            5       1964
# 1210          60    70.000000    11218            6            5       1992
# 1118          80    85.000000    13825            5            6       1958
# 1084          60    70.049958    13031            6            5       1995
# 158           60   100.000000    12552            7            5       2004
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# ...

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# <h3> Q.5. Fit a linear regression model to this data and compute the RMSE</h3>

# %%
from sklearn.linear_model import Ridge, ElasticNet, LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
from numpy import sqrt

#Fit a linear regression model to this data
#TODO
regr = LinearRegression()
regr.fit(X_train, y_train)

#Compute the RMSE 
#TODO
y_test = train_set['SalePrice']
X_test= train_set.drop('SalePrice', axis=1)
y_pred = log_rgr.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, y_pred))

print(rmse)
# Out:
# 17108.648177189025

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# <h3> Q.6.0 Fit lasso regression to training data with alpha 20. (Bonus: You could try CV to find the best alpha within a range)</h3>

# %%
from sklearn import linear_model
from sklearn.linear_model import Lasso

#TODO: fit a Lasso regression model to this data
# Create model

model_l=Lasso(alpha=20)

# Fit model
model_l.fit(X_train, y_train)



#Compute the RMSE 
#TODO
rmse = sqrt(mean_squared_error(y_train, y_pred))
print(rmse)
# Out:
# 17108.648177189025

# %% [markdown]
# <h3> Q.6.1 How many columns has the model chosen?</h3>

# %%
#TODO 
print(np.count_nonzero(model_l.coef_))
# Out:
# 193

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# <h3> Q.7. Perform ridge regression with alpha set to 0.1 and normalize to True. (Bonus: You could try CV to find the best alpha within a range).</h3>

# %%
#TODO
# Create model
model_r = Ridge(alpha=0.1, normalize = True)

#Fit model
model_r.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %% [markdown]
# <h3> Q.8. What is your root mean squared error (RMSE)? Comment on your observation</h3>

# %%
#Compute the RMSE 
#TODO
y_pred = model_r.predict(X_test)
meanSquaredError=mean_squared_error(y_test, y_pred)
rootMeanSquaredError = sqrt(meanSquaredError)
print(rootMeanSquaredError)
# Out:
# 19923.63867270917

# %% [markdown]
# ## Elastic Net Regression

# %% [markdown]
# <h3> Q.9. Perform elastic net regression with different values of alpha (0.01, 0.1 and 20). Compute the RMSE as well.

# %%
#TODO: fit the Elastic net regression model to this data
model_ElasticNet=ElasticNet(alpha=0.01)
model_ElasticNet.fit(X_train,y_train)

y_pred = model_ElasticNet.predict(X_test)
meanSquaredError=mean_squared_error(y_test, y_pred)
rootMeanSquaredError = sqrt(meanSquaredError)
print( rootMeanSquaredError)
# Out:
# 22070.38059424544
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 259575670120.90808, tolerance: 615098412.8205525
#   positive)

# %% [markdown]
# <h3>Q.10. Create a new text cell in your Notebook: Complete a 50-100 word summary
#     (or short description of your thinking in applying this week's learning to the solution)
#      of your experience in this assignment. Include:
# <br>
# What was your incoming experience with this model, if any?
# what steps you took, what obstacles you encountered.
# how you link this exercise to real-world, machine learning problem-solving. (What steps were missing? What else do you need to learn?)
# This summary allows your instructor to know how you are doing and allot points for your effort in thinking and planning, and making connections to real-world work.
# </h3>

# %%
#update: finished the tasks.Looks like Lasso regression and linear showed both the same rmse. Elastic net reression ,however,gave the highest error
