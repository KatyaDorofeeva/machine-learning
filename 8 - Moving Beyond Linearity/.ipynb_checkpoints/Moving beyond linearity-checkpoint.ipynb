# %% [markdown]
# # Assignment 8: Moving Beyond Linearity

# %% [markdown]
# Dataset(s) needed:
# Hitters data frame of the ISLR library SF-DAT-21. In this assignment, we're going to predict Salary based on Hits as the only independent variable.

# %%
import pandas as pd

train = pd.read_csv('Hitters.csv')
train.head(10)
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
# 6    185    37      1    23    8     21      2     214     42       1     30
# 7    298    73      0    24   24      7      3     509    108       0     41
# 8    323    81      6    26   32      8      2     341     86       6     32
# 9    401    92     17    49   66     65     13    5206   1332     253    784
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N
# 5   336     194      A        W      282      421      25   750.0         A
# 6     9      24      N        E       76      127       7    70.0         A
# 7    37      12      A        W      121      283       9   100.0         A
# 8    34       8      N        W      143      290      19    75.0         N
# 9   890     866      A        E        0        0       0  1100.0         A

# %% [markdown]
# <h3> Q.1. Replace missing values in the dataset by the mean</h3>

# %%
means = train.mean()
train = train.fillna(means)
train.isnull().sum()#TODO
# Out:
# AtBat        0
# Hits         0
# HmRun        0
# Runs         0
# RBI          0
# Walks        0
# Years        0
# CAtBat       0
# CHits        0
# CHmRun       0
# CRuns        0
# CRBI         0
# CWalks       0
# League       0
# Division     0
# PutOuts      0
# Assists      0
# Errors       0
# Salary       0
# NewLeague    0
# dtype: int64

# %% [markdown]
# <h3> Q.2. Graph a scatter plot to visualize the relationship between Hits and Salary</h3>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(train['Hits'], train['Salary'])
ax.set_xlabel('Hits')
ax.set_ylabel('Salary')
plt.show()
#TODO

# %% [markdown]
# <h3> Q.3. Apply Linear Regression on the Hitters data to predict 'Salary' depending only on 'Hits' as the independent variable. Print out the slope and intercept coefficients.
# </h3>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# TODO: Split the data into 70/30 train/test datasets

X = train['Hits']
y = train['Salary']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)



# TODO: Fit linear regression model
lingr = LinearRegression()
lingr.fit(X_train.values.reshape(-1,1), y_train)

# TODO: print the slope and intercept
print(lingr.coef_)
print(lingr.intercept_)
# Out:
# [2.67265151]
# 258.3617421213528

# %% [markdown]
# <h3> Q.4. Compute the RMSE of the model obtained above</h3>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt


y_pred = lingr.predict(X_test.values.reshape(-1,1))

print(sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 414.4855851467615

# %% [markdown]
# <h3> Q.5. Graph the linear regression model obtained on the data</h3>

# %%
# TODO:
import numpy as np


def visualize_linearregr(X, y, plot):
    plt.scatter(X, y, facecolor='None', edgecolor='k', alpha=0.3)
    plt.plot(lingr_vis, plot)
    plt.show()



visualize_linearregr(X_test, y_test, lingr.predict(lingr_vis))

# %% [markdown]
# <h3> Q.6. Construct a polynomial regression model with degree 2 to predict 'Salary' depending only on 'Hits' as the independent variable. Compute the RMSE and Plot your result.
# </h3>

# %%
import numpy as np

# Generate weights for polynomial function with degree 2
weights = np.polyfit(X_train,y_train, 2)
print(weights)

# Generate model with the given weights
poly_model = np.poly1d(weights)

# Prediction on test set
pred_pol = poly_model(X_test)

# TODO: Compute the RMSE
#X_test = X_test.reshape(-1,1)
pred_pol = poly_model(X_test)

rms = sqrt(mean_squared_error(y_test, pred_pol))
print(rms)
# TODO: Plot the visualisation
poly_regr = np.linspace(X_test.min(),X_test.max())
plot = poly_model(poly_regr)
visualize_linearregr(X_test, y_test, poly_model(poly_regr))
# Out:
# [ 2.06714107e-02 -1.68855257e+00  4.43517426e+02]
# 397.5813824199521

# %% [markdown]
# <h3> Q.7. Create a cubic spline with 3 knots at 40, 100 and 150</h3>

# %%
from patsy import dmatrix
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Generate a cubic spline with 3 knots at 25, 40 and 60
transformed_x =dmatrix("bs(train, knots=(40,100,150), degree=3, include_intercept=False)", {"train": X_train},return_type='dataframe')

# Fit a generalized linear models on the transformed dataset
fit_glm = sm.GLM(y_train, transformed_x).fit()

# Prediction
pred_glm = fit_glm.predict(dmatrix("bs(valid, knots=(40,100,150), include_intercept=False)", {"valid": X_test}, return_type='dataframe'))

# TODO: Compute the RMSE 
rms = sqrt(mean_squared_error(y_test, pred_glm))
print(rms)

# TODO: Plot the visualisation
lin = np.linspace(X_test.min(), X_test.max())
pred_glm_vis = fit_glm.predict(dmatrix("bs(xp, knots=(40,100,150), include_intercept=False)", {"xp": lin}, return_type='dataframe'))

visualize_linearregr(X_test, y_test, pred_glm_vis)
# Out:
# 422.7573763501608

# %% [markdown]
# <h3> Q.8. Create a natural cubic spline on the data to predict 'Salary' based on 'Hits'</h3>

# %%
# Generate natural cubic spline
transformed_x = dmatrix("cr(train,df = 3)", {"train": X_train}, return_type='dataframe')
fit_spline = sm.GLM(y_train, transformed_x).fit()

# TODO: Compute the RMSE 
pred_spline = fit_spline.predict(dmatrix("cr(valid, df=3)", {"valid": X_test}, return_type='dataframe'))
rms = sqrt(mean_squared_error(y_test, pred_spline))
print(rms)

# Visualization
lin = np.linspace(X_test.min(),X_test.max())
pred_spline = fit_spline.predict(dmatrix("cr(xp, df=3)", {"xp": lin}, return_type='dataframe'))
visualize_linearregr(X_test, y_test, pred_spline)

# TODO: Plot the visualisation
# Out:
# 405.9732360282033

# %% [markdown]
# <h3> Q.9. Which model performed the best?</h3>

# %%
#Natural cubic spine showed the best results
